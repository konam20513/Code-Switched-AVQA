# %%
import torch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# json_file = "/home/ankitk/Desktop/AVQA/translated_train.json"
# new = pd.read_json(json_file)
import pandas as pd
import json
import tensorflow as tf
import torch
import numpy as np

json_file = "/kaggle/input/kkkkkkkkkkkkkk/merged_data_10000_ours.json"

data = []
with open(json_file, 'r') as file:
    for line in file:
        data.append(json.loads(line))

train_df = pd.DataFrame(data)
# Out:
# 2024-03-10 06:04:58.407716: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-10 06:04:58.407852: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-10 06:04:58.570930: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
train_df.head()
# Out:
#    video_id  question_id                             type  \
# 0  00000136           17  ["Audio-Visual", "Comparative"]
# 1  00000250           23  ["Audio-Visual", "Existential"]
# 2  00000225           27  ["Audio-Visual", "Existential"]
# 3  00000152           30  ["Audio-Visual", "Existential"]
# 4  00000085           32  ["Audio-Visual", "Existential"]
#
#                                     question_content       templ_values  \
# 0  Is the instrument on the <LR> louder than the ...  ["left", "right"]
# 1       Is the <Object> in the video always playing?      ["accordion"]
# 2                              Is there a voiceover?                 []
# 3    Is this sound from the instrument in the video?                 []
# 4                              Is there a voiceover?                 []
#
#    question_deleted anser                                           question  \
# 0                 0    no  Is the instrument on the left louder than the ...
# 1                 0   yes      Is the accordion in the video always playing?
# 2                 0   yes                              Is there a voiceover?
# 3                 0   yes    Is this sound from the instrument in the video?
# 4                 0    no                              Is there a voiceover?
#
#                                          Quest_hindi ans_hindi
# 0  क्या बायीं ओर का वाद्ययंत्र दाहिनी ओर के वाद्य...      नहीं
# 1      क्या वीडियो में अकॉर्डियन हमेशा बजता रहता है?       हाँ
# 2                               क्या कोई वॉयसओवर है?       हाँ
# 3        क्या यह ध्वनि वीडियो में मौजूद उपकरण की है?       हाँ
# 4                               क्या कोई वॉयसओवर है?      नहीं

# %%
import os
import numpy as np

def concatenate_arrays(folder_path):
    arrays = []
    for filename in os.listdir(folder_path):
        if filename.endswith('.npy'):
            array_path = os.path.join(folder_path, filename)
            array = np.load(array_path)
            arrays.append(array)
    #concatenated_array = np.concatenate(arrays, axis=1)
    return arrays

folder_path = '/kaggle/input/embeddingsdata/video_features_new/video_features_new'
result_array = concatenate_arrays(folder_path)
video_array = np.array(result_array)
print(video_array.shape)
# Out:
# (5870, 768)

# %%
arr = np.load("/kaggle/input/embeddingsdata/video_features_new/video_features_new/00000002.npy")
print(arr.shape)
# Out:
# (768,)

# %%
hinglish_array = np.load("/kaggle/input/embeddingsdata/embeddings.npy")
hinglish_array = hinglish_array[0:5870]
print(hinglish_array.shape)

english_array = np.load("/kaggle/input/english-question-embeddings/english_question_embeddings.npy")
english_array = english_array[0:5870]
print(english_array.shape)
# Out:
# (5870, 768)
# (5870, 768)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
train_df['labels'] = le.fit_transform(train_df['anser'])
train_df = train_df[0:5870]
train_df.head()
# Out:
#    video_id  question_id                             type  \
# 0  00000136           17  ["Audio-Visual", "Comparative"]
# 1  00000250           23  ["Audio-Visual", "Existential"]
# 2  00000225           27  ["Audio-Visual", "Existential"]
# 3  00000152           30  ["Audio-Visual", "Existential"]
# 4  00000085           32  ["Audio-Visual", "Existential"]
#
#                                     question_content       templ_values  \
# 0  Is the instrument on the <LR> louder than the ...  ["left", "right"]
# 1       Is the <Object> in the video always playing?      ["accordion"]
# 2                              Is there a voiceover?                 []
# 3    Is this sound from the instrument in the video?                 []
# 4                              Is there a voiceover?                 []
#
#    question_deleted anser                                           question  \
# 0                 0    no  Is the instrument on the left louder than the ...
# 1                 0   yes      Is the accordion in the video always playing?
# 2                 0   yes                              Is there a voiceover?
# 3                 0   yes    Is this sound from the instrument in the video?
# 4                 0    no                              Is there a voiceover?
#
#                                          Quest_hindi ans_hindi  labels
# 0  क्या बायीं ओर का वाद्ययंत्र दाहिनी ओर के वाद्य...      नहीं       0
# 1      क्या वीडियो में अकॉर्डियन हमेशा बजता रहता है?       हाँ       1
# 2                               क्या कोई वॉयसओवर है?       हाँ       1
# 3        क्या यह ध्वनि वीडियो में मौजूद उपकरण की है?       हाँ       1
# 4                               क्या कोई वॉयसओवर है?      नहीं       0

# %%
train_df = train_df[['video_id', 'question_id', 'type', 'labels']]

# %%
from sklearn.model_selection import train_test_split
X_trainv, X_testv, y_train, y_test = train_test_split(video_array, train_df['labels'], test_size=0.2, random_state=42)

print("For Video:")
print("X_train shape:", X_trainv.shape)
print("X_test shape:", X_testv.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)


X_traint, X_testt, y_train, y_test = train_test_split(hinglish_array, train_df['labels'], test_size=0.2, random_state=42)

print("For Audio:")
print("X_train shape:", X_traint.shape)
print("X_test shape:", X_testt.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# For Video:
# X_train shape: (4696, 768)
# X_test shape: (1174, 768)
# y_train shape: (4696,)
# y_test shape: (1174,)
# For Audio:
# X_train shape: (4696, 768)
# X_test shape: (1174, 768)
# y_train shape: (4696,)
# y_test shape: (1174,)

# %%
def create_model():


    input_1 = tf.keras.Input(shape=[768, 1])
    x1 = tf.keras.layers.Conv1D(32, 3, activation = 'relu', padding = 'same', name= "cnn1")(input_1)
    x1 = tf.keras.layers.MaxPooling1D(name= "maxpool1")(x1)
    x1 = tf.keras.layers.Flatten()(x1)


    input_2 = tf.keras.Input(shape=[768, 1])
    x2 = tf.keras.layers.Conv1D(32, 3, activation = 'relu', padding = 'same')(input_2)
    x2 = tf.keras.layers.MaxPooling1D()(x2)
    x2 = tf.keras.layers.Flatten()(x2)
    

    concatenated = tf.keras.layers.Concatenate(axis=1)([x1, x2])
    x = tf.keras.layers.Dense(200, activation='relu',  name= "dense1")(concatenated)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Dense(90, activation = 'relu', name= "dense2")(x)
    x = tf.keras.layers.Dropout(0.2)(x)
    x = tf.keras.layers.Dense(56, activation = 'relu', name= "dense3")(x)
    output = tf.keras.layers.Dense(2, activation='softmax', name= "output")(x)
    model = tf.keras.Model(inputs= [input_1, input_2], outputs = output)
    return model
hinglish_model = create_model()
hinglish_model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 768, 1)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_1       │ (None, 768, 1)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ cnn1 (Conv1D)       │ (None, 768, 32)   │        128 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d (Conv1D)     │ (None, 768, 32)   │        128 │ input_layer_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ maxpool1            │ (None, 384, 32)   │          0 │ cnn1[0][0]        │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d       │ (None, 384, 32)   │          0 │ conv1d[0][0]      │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 12288)     │          0 │ maxpool1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_1 (Flatten) │ (None, 12288)     │          0 │ max_pooling1d[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 24576)     │          0 │ flatten[0][0],    │
# │ (Concatenate)       │                   │            │ flatten_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense1 (Dense)      │ (None, 200)       │  4,915,400 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 200)       │        800 │ dense1[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense2 (Dense)      │ (None, 90)        │     18,090 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 90)        │          0 │ dense2[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense3 (Dense)      │ (None, 56)        │      5,096 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ output (Dense)      │ (None, 2)         │        114 │ dense3[0][0]      │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 4,939,756 (18.84 MB)
#  Trainable params: 4,939,356 (18.84 MB)
#  Non-trainable params: 400 (1.56 KB)

# %%
lr = 1e-3
#import tensorflow_addons as tfa
optimizer = tf.keras.optimizers.Adam(learning_rate= lr)
#optimizer = tfa.optimizers.RectifiedAdam(learning_rate= lr)
# Compile the model with the Riemannian optimizer
hinglish_model.compile(
    optimizer=optimizer,
    loss= tf.keras.losses.SparseCategoricalCrossentropy(), #focal_loss(alpha=0.25, gamma=2.0),#tf.keras.losses.SparseCategoricalCrossentropy(),  #from_logits=True
    metrics= ['accuracy']  #[tf.keras.metrics.SparseCategoricalAccuracy()],
)


reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor = 'val_accuracy',
                                                 factor = 0.2,
                                                 patience = 1,
                                                 verbose = 1,
                                                 min_delta = 1e-4,
                                                 min_lr = 1e-15,
                                                 mode = 'max')

earlystopping = tf.keras.callbacks.EarlyStopping(monitor = 'val_accuracy',
                                                 min_delta = 1e-4,
                                                 patience = 70,
                                                 mode = 'max',
                                                 restore_best_weights = True,
                                                 verbose = 1)

callbacks = [earlystopping, reduce_lr]#reduce_lr]

# %%
import time
start_time = time.time()
history = hinglish_model.fit([X_trainv, X_traint], y_train,
                   validation_data =  ([X_testv, X_testt], y_test),
                   batch_size = 16,
                   epochs = 20,
                   callbacks = callbacks)

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Epoch 1/20
#  24/294 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5440 - loss: 0.7838
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1710050758.540866     107 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 12s 19ms/step - accuracy: 0.6499 - loss: 0.6477 - val_accuracy: 0.6678 - val_loss: 0.6596 - learning_rate: 0.0010
# Epoch 2/20
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.6940 - loss: 0.5616 - val_accuracy: 0.6729 - val_loss: 0.5913 - learning_rate: 0.0010
# Epoch 3/20
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7215 - loss: 0.5408 - val_accuracy: 0.6925 - val_loss: 0.6359 - learning_rate: 0.0010
# Epoch 4/20
# 290/294 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7221 - loss: 0.5376
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7220 - loss: 0.5376 - val_accuracy: 0.6891 - val_loss: 0.5925 - learning_rate: 0.0010
# Epoch 5/20
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7381 - loss: 0.4999 - val_accuracy: 0.7019 - val_loss: 0.5990 - learning_rate: 2.0000e-04
# Epoch 6/20
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.7650 - loss: 0.4774 - val_accuracy: 0.7027 - val_loss: 0.6093 - learning_rate: 2.0000e-04
# Epoch 7/20
# 290/294 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7616 - loss: 0.4675
# Epoch 7: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.7616 - loss: 0.4676 - val_accuracy: 0.6925 - val_loss: 0.6282 - learning_rate: 2.0000e-04
# Epoch 8/20
# 288/294 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7734 - loss: 0.4536
# Epoch 8: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7736 - loss: 0.4534 - val_accuracy: 0.6934 - val_loss: 0.6221 - learning_rate: 4.0000e-05
# Epoch 9/20
# 286/294 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7785 - loss: 0.4487
# Epoch 9: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.7786 - loss: 0.4486 - val_accuracy: 0.6899 - val_loss: 0.6217 - learning_rate: 8.0000e-06
# Epoch 10/20
# 293/294 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7840 - loss: 0.4438
# Epoch 10: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7840 - loss: 0.4438 - val_accuracy: 0.6899 - val_loss: 0.6218 - learning_rate: 1.6000e-06
# Epoch 11/20
# 289/294 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7959 - loss: 0.4280
# Epoch 11: ReduceLROnPlateau reducing learning rate to 6.400000529538374e-08.
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.7957 - loss: 0.4282 - val_accuracy: 0.6917 - val_loss: 0.6229 - learning_rate: 3.2000e-07
# Epoch 12/20
# 292/294 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7973 - loss: 0.4317
# Epoch 12: ReduceLROnPlateau reducing learning rate to 1.2800001059076749e-08.
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.7973 - loss: 0.4317 - val_accuracy: 0.6891 - val_loss: 0.6218 - learning_rate: 6.4000e-08
# Epoch 13/20
# 289/294 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7877 - loss: 0.4323
# Epoch 13: ReduceLROnPlateau reducing learning rate to 2.5600002118153498e-09.
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.7877 - loss: 0.4324 - val_accuracy: 0.6908 - val_loss: 0.6219 - learning_rate: 1.2800e-08
# Epoch 14/20
# 288/294 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7972 - loss: 0.4359
# Epoch 14: ReduceLROnPlateau reducing learning rate to 5.1200004236307e-10.
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7970 - loss: 0.4360 - val_accuracy: 0.6917 - val_loss: 0.6236 - learning_rate: 2.5600e-09
# Epoch 15/20
# 291/294 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7826 - loss: 0.4441
# Epoch 15: ReduceLROnPlateau reducing learning rate to 1.0240001069306004e-10.
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7827 - loss: 0.4440 - val_accuracy: 0.6882 - val_loss: 0.6224 - learning_rate: 5.1200e-10
# Epoch 16/20
# 290/294 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7888 - loss: 0.4402
# Epoch 16: ReduceLROnPlateau reducing learning rate to 2.0480002416167767e-11.
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.7888 - loss: 0.4401 - val_accuracy: 0.6899 - val_loss: 0.6226 - learning_rate: 1.0240e-10
# Epoch 17/20
# 290/294 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7808 - loss: 0.4456
# Epoch 17: ReduceLROnPlateau reducing learning rate to 4.096000622011431e-12.
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7810 - loss: 0.4455 - val_accuracy: 0.6917 - val_loss: 0.6228 - learning_rate: 2.0480e-11
# Epoch 18/20
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7881 - loss: 0.4393
# Epoch 18: ReduceLROnPlateau reducing learning rate to 8.192000897078167e-13.
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.7881 - loss: 0.4393 - val_accuracy: 0.6917 - val_loss: 0.6213 - learning_rate: 4.0960e-12
# Epoch 19/20
# 293/294 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7982 - loss: 0.4235
# Epoch 19: ReduceLROnPlateau reducing learning rate to 1.6384001360475466e-13.
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.7981 - loss: 0.4235 - val_accuracy: 0.6908 - val_loss: 0.6234 - learning_rate: 8.1920e-13
# Epoch 20/20
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7846 - loss: 0.4379
# Epoch 20: ReduceLROnPlateau reducing learning rate to 3.2768002178849846e-14.
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.7846 - loss: 0.4379 - val_accuracy: 0.6891 - val_loss: 0.6217 - learning_rate: 1.6384e-13
# Restoring model weights from the end of the best epoch: 6.
# --- 41.349398374557495 seconds ---

# %%
import matplotlib.pyplot as plt

def plot_history(history):
    # Plot training & validation accuracy values
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')
    plt.show()

    # Plot training & validation loss values
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')
    plt.show()
    
plot_history(history)

# %%
english_model = create_model()
english_model.summary()
# Out:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_4       │ (None, 768, 1)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_5       │ (None, 768, 1)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ cnn1 (Conv1D)       │ (None, 768, 32)   │        128 │ input_layer_4[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_2 (Conv1D)   │ (None, 768, 32)   │        128 │ input_layer_5[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ maxpool1            │ (None, 384, 32)   │          0 │ cnn1[0][0]        │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_2     │ (None, 384, 32)   │          0 │ conv1d_2[0][0]    │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_4 (Flatten) │ (None, 12288)     │          0 │ maxpool1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_5 (Flatten) │ (None, 12288)     │          0 │ max_pooling1d_2[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 24576)     │          0 │ flatten_4[0][0],  │
# │ (Concatenate)       │                   │            │ flatten_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense1 (Dense)      │ (None, 200)       │  4,915,400 │ concatenate_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 200)       │        800 │ dense1[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense2 (Dense)      │ (None, 90)        │     18,090 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 90)        │          0 │ dense2[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense3 (Dense)      │ (None, 56)        │      5,096 │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ output (Dense)      │ (None, 2)         │        114 │ dense3[0][0]      │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 4,939,756 (18.84 MB)
#  Trainable params: 4,939,356 (18.84 MB)
#  Non-trainable params: 400 (1.56 KB)

# %%
lr = 1e-3
#import tensorflow_addons as tfa
optimizer = tf.keras.optimizers.Adam(learning_rate= lr)
#optimizer = tfa.optimizers.RectifiedAdam(learning_rate= lr)
# Compile the model with the Riemannian optimizer
english_model.compile(
    optimizer=optimizer,
    loss= tf.keras.losses.SparseCategoricalCrossentropy(), #focal_loss(alpha=0.25, gamma=2.0),#tf.keras.losses.SparseCategoricalCrossentropy(),  #from_logits=True
    metrics= ['accuracy']  #[tf.keras.metrics.SparseCategoricalAccuracy()],
)



reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor = 'val_accuracy',
                                                 factor = 0.2,
                                                 patience = 1,
                                                 verbose = 1,
                                                 min_delta = 1e-4,
                                                 min_lr = 1e-15,
                                                 mode = 'max')

earlystopping = tf.keras.callbacks.EarlyStopping(monitor = 'val_accuracy',
                                                 min_delta = 1e-4,
                                                 patience = 70,
                                                 mode = 'max',
                                                 restore_best_weights = True,
                                                 verbose = 1)

callbacks = [earlystopping, reduce_lr]#reduce_lr]

# %%
X_trainte, X_testte, y_train, y_test = train_test_split(english_array, train_df['labels'], test_size=0.2, random_state=42)

print("For Audio:")
print("X_train shape:", X_trainte.shape)
print("X_test shape:", X_testte.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# For Audio:
# X_train shape: (4696, 768)
# X_test shape: (1174, 768)
# y_train shape: (4696,)
# y_test shape: (1174,)

# %%
import time
start_time = time.time()
history = english_model.fit([X_trainv, X_trainte], y_train,
                   validation_data =  ([X_testv, X_testte], y_test),
                   batch_size = 16,
                   epochs = 20,
                   callbacks = callbacks)

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Epoch 1/20
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.6697 - loss: 0.6174 - val_accuracy: 0.6499 - val_loss: 0.6025 - learning_rate: 0.0010
# Epoch 2/20
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.6913 - loss: 0.5630 - val_accuracy: 0.6721 - val_loss: 0.5835 - learning_rate: 0.0010
# Epoch 3/20
# 290/294 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6969 - loss: 0.5570
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.6969 - loss: 0.5570 - val_accuracy: 0.6525 - val_loss: 0.6015 - learning_rate: 0.0010
# Epoch 4/20
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.7125 - loss: 0.5277 - val_accuracy: 0.6806 - val_loss: 0.5944 - learning_rate: 2.0000e-04
# Epoch 5/20
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7246 - loss: 0.5159
# Epoch 5: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.7246 - loss: 0.5159 - val_accuracy: 0.6780 - val_loss: 0.6014 - learning_rate: 2.0000e-04
# Epoch 6/20
# 288/294 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7461 - loss: 0.4973
# Epoch 6: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.7460 - loss: 0.4974 - val_accuracy: 0.6806 - val_loss: 0.5995 - learning_rate: 4.0000e-05
# Epoch 7/20
# 286/294 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7420 - loss: 0.4904
# Epoch 7: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.7422 - loss: 0.4905 - val_accuracy: 0.6797 - val_loss: 0.6006 - learning_rate: 8.0000e-06
# Epoch 8/20
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7567 - loss: 0.4848
# Epoch 8: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.7567 - loss: 0.4849 - val_accuracy: 0.6789 - val_loss: 0.6013 - learning_rate: 1.6000e-06
# Epoch 9/20
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.7544 - loss: 0.4885 - val_accuracy: 0.6814 - val_loss: 0.6016 - learning_rate: 3.2000e-07
# Epoch 10/20
# 288/294 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7396 - loss: 0.4952
# Epoch 10: ReduceLROnPlateau reducing learning rate to 6.400000529538374e-08.
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7397 - loss: 0.4951 - val_accuracy: 0.6806 - val_loss: 0.6019 - learning_rate: 3.2000e-07
# Epoch 11/20
# 290/294 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7353 - loss: 0.4911
# Epoch 11: ReduceLROnPlateau reducing learning rate to 1.2800001059076749e-08.
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7355 - loss: 0.4911 - val_accuracy: 0.6797 - val_loss: 0.6018 - learning_rate: 6.4000e-08
# Epoch 12/20
# 283/294 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7385 - loss: 0.5021
# Epoch 12: ReduceLROnPlateau reducing learning rate to 2.5600002118153498e-09.
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7385 - loss: 0.5019 - val_accuracy: 0.6806 - val_loss: 0.6016 - learning_rate: 1.2800e-08
# Epoch 13/20
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.7643 - loss: 0.4950 - val_accuracy: 0.6831 - val_loss: 0.6014 - learning_rate: 2.5600e-09
# Epoch 14/20
# 284/294 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7573 - loss: 0.4984
# Epoch 14: ReduceLROnPlateau reducing learning rate to 5.1200004236307e-10.
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7571 - loss: 0.4982 - val_accuracy: 0.6814 - val_loss: 0.6015 - learning_rate: 2.5600e-09
# Epoch 15/20
# 285/294 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7595 - loss: 0.4780
# Epoch 15: ReduceLROnPlateau reducing learning rate to 1.0240001069306004e-10.
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.7591 - loss: 0.4785 - val_accuracy: 0.6797 - val_loss: 0.6014 - learning_rate: 5.1200e-10
# Epoch 16/20
# 293/294 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7545 - loss: 0.4907
# Epoch 16: ReduceLROnPlateau reducing learning rate to 2.0480002416167767e-11.
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.7544 - loss: 0.4907 - val_accuracy: 0.6789 - val_loss: 0.6015 - learning_rate: 1.0240e-10
# Epoch 17/20
# 292/294 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7475 - loss: 0.4886
# Epoch 17: ReduceLROnPlateau reducing learning rate to 4.096000622011431e-12.
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.7475 - loss: 0.4887 - val_accuracy: 0.6789 - val_loss: 0.6013 - learning_rate: 2.0480e-11
# Epoch 18/20
# 287/294 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7476 - loss: 0.4985
# Epoch 18: ReduceLROnPlateau reducing learning rate to 8.192000897078167e-13.
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7476 - loss: 0.4985 - val_accuracy: 0.6823 - val_loss: 0.6023 - learning_rate: 4.0960e-12
# Epoch 19/20
# 287/294 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7371 - loss: 0.4996
# Epoch 19: ReduceLROnPlateau reducing learning rate to 1.6384001360475466e-13.
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.7373 - loss: 0.4995 - val_accuracy: 0.6814 - val_loss: 0.6014 - learning_rate: 8.1920e-13
# Epoch 20/20
# 285/294 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7516 - loss: 0.4918
# Epoch 20: ReduceLROnPlateau reducing learning rate to 3.2768002178849846e-14.
# 294/294 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.7513 - loss: 0.4919 - val_accuracy: 0.6797 - val_loss: 0.6019 - learning_rate: 1.6384e-13
# Restoring model weights from the end of the best epoch: 13.
# --- 37.76684808731079 seconds ---

# %%
def plot_history(history):
    # Plot training & validation accuracy values
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('Model accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')
    plt.show()

    # Plot training & validation loss values
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('Model loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')
    plt.show()
    
plot_history(history)
